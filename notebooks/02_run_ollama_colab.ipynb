# %%
# !git clone https://github.com/songhahyun/dermatology-rag-chatbot.git /content/dermatology-rag-chatbot
# %cd /content/dermatology-rag-chatbot

# %%
# !sudo apt-get install zstd

# %%
# !python src/colab_ollama_runner.py \
#   --install-ollama \
#   --repo-dir /content/dermatology-rag-chatbot \
#   --model qwen2.5:7b-instruct

# %%
# !python src/colab_ollama_runner.py \
#   --install-ollama \
#   --install-python-deps \
#   --keep-alive "90m" \
#   --inputs data/raw/TL_내과_통합.json

# %%
# !python src/colab_ollama_runner.py \
#   --install-ollama \
#   --install-python-deps \
#   --keep-alive "90m" \
#   --inputs data/raw/TL_내과_통합.json \
#   --checkpoint-every 50
